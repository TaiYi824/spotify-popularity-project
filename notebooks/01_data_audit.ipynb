# %%
import pandas as pd

df = pd.read_csv("../data/raw/spotify_data_clean.csv")
df.head()

# %%
df.shape

# %%
df.info()

# %%
df.isna().sum().sort_values(ascending=False)

# %%
df.describe(include="all").T

# %%
df.duplicated().sum()

# %%
pd.to_datetime(df["album_release_date"], errors="coerce").describe()
